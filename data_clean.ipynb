# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
# %matplotlib inline

# %%
data_dir = "./dataset/yelp_dataset/"

# %%
business_data = pd.read_csv(data_dir + "business.csv")
# Out:
# /Users/wenyuangao/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (16,35,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data = pd.read_csv(data_dir + "restaurant_review.csv")
# Out:
# /Users/wenyuangao/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data
# Out:
#         Unnamed: 0             business_id  \
# 0                0  QXAEGFB4oINsVuTFxEYKFQ
# 1                1  QXAEGFB4oINsVuTFxEYKFQ
# 2                2  QXAEGFB4oINsVuTFxEYKFQ
# 3                3  QXAEGFB4oINsVuTFxEYKFQ
# 4                4  QXAEGFB4oINsVuTFxEYKFQ
# 5                5  QXAEGFB4oINsVuTFxEYKFQ
# 6                6  QXAEGFB4oINsVuTFxEYKFQ
# 7                7  QXAEGFB4oINsVuTFxEYKFQ
# 8                8  QXAEGFB4oINsVuTFxEYKFQ
# 9                9  QXAEGFB4oINsVuTFxEYKFQ
# 10              10  QXAEGFB4oINsVuTFxEYKFQ
# 11              11  QXAEGFB4oINsVuTFxEYKFQ
# 12              12  QXAEGFB4oINsVuTFxEYKFQ
# 13              13  QXAEGFB4oINsVuTFxEYKFQ
# 14              14  QXAEGFB4oINsVuTFxEYKFQ
# 15              15  QXAEGFB4oINsVuTFxEYKFQ
# 16              16  QXAEGFB4oINsVuTFxEYKFQ
# 17              17  QXAEGFB4oINsVuTFxEYKFQ
# 18              18  QXAEGFB4oINsVuTFxEYKFQ
# 19              19  QXAEGFB4oINsVuTFxEYKFQ
# 20              20  QXAEGFB4oINsVuTFxEYKFQ
# ...

# %%
data.shape
# Out:
# (4201685, 11)

# %%
five_star = data[data['stars'] == 5].text.values

# %%
five_star.shape
# Out:
# (1652525,)

# %%
f1 = open('res_five_star1000.txt','w')
lst = []
i=0

for te in five_star:
    if (i%100 == 0):
        print(i)
    if (i>1000):
        break
    i+=1
    f1.write(re.sub('[^a-zA-Z0-9!?., ]','',str(te))+'\n')
f1.close()
#       lst.append(re.sub('[^a-zA-Z0-9!?., ]','',str(te)))
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000

# %%
one_star = data[data['stars'] == 1].text.values

# %%
one_star.shape
# Out:
# (498489,)

# %%
f1 = open('res_one_star1000.txt','w')
lst = []
i=0

for te in one_star:
    if (i%100 == 0):
        print(i)
    if (i>1000):
        break
    i+=1
    f1.write(re.sub('[^a-zA-Z0-9!?., ]','',str(te))+'\n')
f1.close()
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000

# %%
! pip3 install gpt_2_simple
! pip3 install tensorflow
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/f6/7b/5ab19bac13810661ff9e2485811553f1dea9a5d611ce846345aed4766bbe/tensorflow-1.13.1-cp36-cp36m-macosx_10_11_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/0f/39/bdd75b08a6fba41f098b6cb091b9e8c7a80e1b4d679a581a0ccd17b10373/tensorboard-1.13.1-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/46/1e/c481d59760cded074d89ff51c99381708111c550ff698934cc296d27df2c/protobuf-3.7.1-cp36-cp36m-macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# ...
#      |████████████████████████████████| 2.0MB 1.3MB/s eta 0:00:01
# ...
#   Using cached https://files.pythonhosted.org/packages/c0/bf/0315ef6a9fd3fc2346e85b0ff1f5f83ca17073f2c31ac719ab2e4da0d4a3/Keras_Preprocessing-1.0.9-py2.py3-none-any.whl
# ...

# %%
! gpt_2_simple.download_gpt2()
# Out:
# /bin/sh: -c: line 1: syntax error: unexpected end of file

# %%
import gpt_2_simple as gpt2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-bfc59e5c3c51> in <module>()
# ----> 1 import gpt_2_simple as gpt2
#
# ModuleNotFoundError: No module named 'gpt_2_simple'
