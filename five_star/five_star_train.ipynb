# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd gdrive/My Drive/FakeYelpReview/
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/FakeYelpReview/'
# /content/gdrive/My Drive/FakeYelpReview/five_star

# %%
cd five_star
# Out:
# [Errno 2] No such file or directory: 'five_star'
# /content/gdrive/My Drive/FakeYelpReview/five_star

# %%
! pip3 install gpt_2_simple 
! pip3 install tensorflow
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/ef/2d/dd/f7105230a9e1558c741e062e37f0cc4683c31c5eabc523d20a
# Successfully built gpt-2-simple
# ...

# %%
% ls
# Out:
# checkpoint/        five_star100.txt  five_star500.txt       models/
# five_star1000.txt  five_star300.txt  five_star_train.ipynb

# %%
! gpt_2_simple finetune five_star500.txt
# Out:
# 2019-04-28 21:43:32.515257: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-04-28 21:43:32.515495: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x19d0520 executing computations on platform Host. Devices:
# 2019-04-28 21:43:32.515529: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-04-28 21:43:32.676075: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-04-28 21:43:32.676563: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x19cfb80 executing computations on platform CUDA. Devices:
# 2019-04-28 21:43:32.676593: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# ...

# %%
! gpt_2_simple generate
# Out:
# 2019-04-28 22:08:54.086006: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-04-28 22:08:54.086206: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2e26520 executing computations on platform Host. Devices:
# 2019-04-28 22:08:54.086240: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-04-28 22:08:54.255405: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-04-28 22:08:54.255913: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2e25b80 executing computations on platform CUDA. Devices:
# 2019-04-28 22:08:54.255946: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# ...
